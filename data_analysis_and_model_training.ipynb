# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Task 1 : Data Preparation

# %%
df = pd.read_csv('/home/saif/Desktop/Customer Churn Analysis and Prediction/Telco_Customer_Churn_Dataset  (1).csv')

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4086  Female              0     Yes         No      72          Yes
# 1664  Female              0      No         No      46          Yes
# 5850    Male              1      No         No      20          Yes
# 5767  Female              0     Yes         No      65          Yes
# 6740  Female              1      No         No      40          Yes
# 790   Female              0     Yes        Yes      60           No
# 1654    Male              0     Yes        Yes       1          Yes
# 1597    Male              0     Yes         No      48          Yes
# 836     Male              0     Yes        Yes      62          Yes
# 4060    Male              0     Yes        Yes      54          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 4086               Yes             DSL                  Yes
# 1664               Yes     Fiber optic                   No
# 5850                No     Fiber optic                   No
# 5767                No             DSL                   No
# 6740                No     Fiber optic                  Yes
# 790   No phone service             DSL                  Yes
# 1654                No              No  No internet service
# 1597               Yes     Fiber optic                  Yes
# 836                 No             DSL                  Yes
# 4060               Yes             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4086                  Yes                  Yes                  Yes
# 1664                   No                   No                   No
# 5850                   No                   No                   No
# 5767                   No                   No                  Yes
# 6740                  Yes                   No                   No
# 790                    No                  Yes                  Yes
# 1654  No internet service  No internet service  No internet service
# 1597                  Yes                  Yes                   No
# 836                    No                  Yes                  Yes
# 4060                   No                  Yes                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 4086                  Yes                   No        Two year
# 1664                  Yes                  Yes  Month-to-month
# 5850                   No                   No  Month-to-month
# 5767                  Yes                   No        Two year
# 6740                   No                   No  Month-to-month
# 790                   Yes                  Yes        Two year
# 1654  No internet service  No internet service        One year
# 1597                  Yes                   No        Two year
# 836                    No                  Yes        One year
# 4060                   No                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 4086               No    Credit card (automatic)           79.20
# 1664               No  Bank transfer (automatic)           96.05
# 5850               No    Credit card (automatic)           71.30
# 5767              Yes    Credit card (automatic)           59.80
# 6740              Yes    Credit card (automatic)           79.20
# 790                No    Credit card (automatic)           59.85
# 1654               No               Mailed check           18.80
# 1597              Yes  Bank transfer (automatic)           96.90
# 836                No    Credit card (automatic)           71.40
# 4060               No    Credit card (automatic)           63.35
#
#       TotalCharges Churn
# 4086       5401.90    No
# 1664       4399.50   Yes
# 5850       1389.20   Yes
# 5767       3808.20    No
# 6740       3233.85   Yes
# 790        3590.20    No
# 1654         18.80    No
# 1597       4473.45    No
# 836        4487.30    No
# 4060       3409.10    No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7010 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7010 non-null   object
#  1   SeniorCitizen     7010 non-null   int64
#  2   Partner           7010 non-null   object
#  3   Dependents        7010 non-null   object
#  4   tenure            7010 non-null   int64
#  5   PhoneService      7010 non-null   object
#  6   MultipleLines     7010 non-null   object
#  7   InternetService   7010 non-null   object
#  8   OnlineSecurity    7010 non-null   object
#  9   OnlineBackup      7010 non-null   object
#  10  DeviceProtection  7010 non-null   object
#  11  TechSupport       7010 non-null   object
#  12  StreamingTV       7010 non-null   object
#  13  StreamingMovies   7010 non-null   object
#  14  Contract          7010 non-null   object
#  15  PaperlessBilling  7010 non-null   object
#  16  PaymentMethod     7010 non-null   object
#  17  MonthlyCharges    7010 non-null   float64
#  18  TotalCharges      7010 non-null   float64
#  19  Churn             7010 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# * As we can see there are 7043 entries
# * there are no missing values

# %%
# Convert TotalCharges to float
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * There is no duplicate rows in the dataset

# %%
#remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# * No null values in the dataset

# %%
#drop rows with missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7010, 20)

# %% [markdown]
# ### Encoding Categorical columns

# %%
df_encoded = df.copy()

# %%
categorical_columns = df_encoded.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
categorical_columns = [col for col in categorical_columns if col not in ['Churn', 'gender','MultipleLines','InternetService','Contract','PaymentMethod']]
categorical_columns
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'PaperlessBilling']

# %%
# Convert all categorical columns
# "Yes" -> 1, "No" -> 0, "No internet service" -> -1
for col in categorical_columns:
    df_encoded[col] = df_encoded[col].apply(lambda x: 1 if x == "Yes" else (-1 if x == "No internet service" else 0))

# %%
# gender -> 1 for males, 0 for females
df_encoded['gender'] = df_encoded['gender'].apply(lambda x: 1 if x == "Male" else 0)
df_encoded.sample(10)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2751       0              0        1           1      19             0
# 3328       0              0        0           0       1             1
# 5246       0              0        0           0       2             1
# 2387       1              0        0           0       5             1
# 6886       0              1        0           0       8             1
# 5614       1              0        1           1      68             1
# 6901       0              0        0           0      30             1
# 1676       0              0        0           0       4             1
# 1657       1              0        0           0      35             1
# 607        1              0        0           1      51             1
#
#          MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 2751  No phone service             DSL               0             0
# 3328                No     Fiber optic               0             0
# 5246                No     Fiber optic               0             0
# 2387               Yes     Fiber optic               0             1
# 6886               Yes     Fiber optic               0             0
# 5614               Yes     Fiber optic               1             1
# 6901               Yes             DSL               0             1
# 1676               Yes     Fiber optic               1             0
# 1657               Yes              No              -1            -1
# 607                 No             DSL               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 2751                 0            0            0                0
# 3328                 0            0            0                0
# 5246                 0            0            1                0
# 2387                 1            0            1                1
# 6886                 1            0            1                1
# 5614                 0            0            0                0
# 6901                 1            0            1                0
# 1676                 0            0            0                0
# 1657                -1           -1           -1               -1
# 607                  0            1            0                0
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 2751  Month-to-month                 1               Mailed check
# 3328  Month-to-month                 1           Electronic check
# 5246  Month-to-month                 1           Electronic check
# 2387  Month-to-month                 0           Electronic check
# 6886  Month-to-month                 0           Electronic check
# 5614        One year                 1  Bank transfer (automatic)
# 6901        One year                 1    Credit card (automatic)
# 1676  Month-to-month                 1           Electronic check
# 1657  Month-to-month                 1           Electronic check
# 607         One year                 0    Credit card (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 2751           24.85        434.80    No
# 3328           70.25         70.25    No
# 5246           79.75        164.50   Yes
# 2387          105.30        550.60    No
# 6886          101.35        780.50   Yes
# 5614           85.50       5696.60    No
# 6901           68.95       2038.70    No
# 1676           80.15        319.85    No
# 1657           25.60        901.25    No
# 607            47.85       2356.75    No

# %%
# MultipleLines -> 1 for yes, 0 for no, -1 for No phone service
df_encoded['MultipleLines'] = df_encoded['MultipleLines'].apply(lambda x: 1 if x == "Yes" else (-1 if x == "No phone service" else 0))
df_encoded.sample(10)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5443       1              0        0           0      26             1
# 5385       1              0        0           0      53             1
# 3204       1              0        0           1      40             1
# 5297       0              0        1           1      54             1
# 3853       1              0        0           0      46             1
# 4904       0              0        0           0      33             1
# 6458       1              0        1           1       6             1
# 4479       0              0        0           0      59             1
# 5543       0              1        0           0      14             1
# 6087       1              0        0           1      26             0
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 5443              0             DSL               0             0
# 5385              1     Fiber optic               0             0
# 3204              0              No              -1            -1
# 5297              0              No              -1            -1
# 3853              1     Fiber optic               0             0
# 4904              1     Fiber optic               0             1
# 6458              0             DSL               1             0
# 4479              1              No              -1            -1
# 5543              0     Fiber optic               1             1
# 6087             -1             DSL               0             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 5443                 0            0            0                0
# 5385                 0            0            1                0
# 3204                -1           -1           -1               -1
# 5297                -1           -1           -1               -1
# 3853                 0            0            0                0
# 4904                 1            0            1                1
# 6458                 0            0            0                0
# 4479                -1           -1           -1               -1
# 5543                 0            0            0                0
# 6087                 0            0            1                0
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 5443  Month-to-month                 0           Electronic check
# 5385  Month-to-month                 0  Bank transfer (automatic)
# 3204        One year                 1  Bank transfer (automatic)
# 5297        Two year                 1  Bank transfer (automatic)
# 3853  Month-to-month                 0  Bank transfer (automatic)
# 4904  Month-to-month                 0           Electronic check
# 6458  Month-to-month                 1           Electronic check
# 4479        Two year                 0           Electronic check
# 5543  Month-to-month                 0           Electronic check
# 6087        One year                 1  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 5443           45.45       1233.15    No
# 5385           85.45       4517.25   Yes
# 3204           20.40        854.90    No
# 5297           20.35       1092.35    No
# 3853           72.80       3249.40    No
# 4904          107.55       3645.50    No
# 6458           49.15        295.65    No
# 4479           24.45       1493.10    No
# 5543           78.85       1043.80    No
# 6087           39.95       1023.75    No

# %%
# label encoding to churn column as Yes to 1 and no to 0
label_encoder = LabelEncoder()
df_encoded["Churn"] = label_encoder.fit_transform(df["Churn"])
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3526       1              1        0           0       5             1
# 4978       0              0        0           0       1             1
# 3571       0              0        0           0      35             1
# 5272       0              0        0           0       6             1
# 6536       1              0        0           0       1             0
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 3526              0             DSL               0             0
# 4978              0             DSL               0             0
# 3571              0             DSL               0             0
# 5272              1     Fiber optic               0             1
# 6536             -1             DSL               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 3526                 1            0            0                0
# 4978                 0            0            0                0
# 3571                 1            0            0                1
# 5272                 0            0            1                0
# 6536                 0            0            0                0
#
#             Contract  PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 3526  Month-to-month                 0  Electronic check           50.35
# 4978  Month-to-month                 1  Electronic check           44.10
# 3571  Month-to-month                 1  Electronic check           62.10
# 5272  Month-to-month                 1  Electronic check           90.10
# 6536  Month-to-month                 0      Mailed check           24.40
#
#       TotalCharges  Churn
# 3526        237.25      1
# 4978         44.10      1
# 3571       2096.10      0
# 5272        521.30      1
# 6536         24.40      0

# %%
# Unique categories of InternetService
df_encoded['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
# Encode DSL as 1 and Fiber optic as 2 and No as 0
df_encoded['InternetService'] = df_encoded['InternetService'].apply(lambda x: 1 if x == "DSL" else (2 if x == "Fiber optic" else 0))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3127       0              0        0           0      29             0
# 6761       1              0        0           0       1             1
# 290        1              1        0           0      24             1
# 5562       0              1        1           0      56             1
# 5237       0              0        0           0      26             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 3127             -1                1               0             1
# 6761              0                0              -1            -1
# 290               1                2               0             0
# 5562              1                2               0             0
# 5237              0                1               0             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 3127                 0            0            0                0
# 6761                -1           -1           -1               -1
# 290                  0            0            0                0
# 5562                 0            1            0                0
# 5237                 1            0            0                0
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 3127  Month-to-month                 1           Electronic check
# 6761  Month-to-month                 1               Mailed check
# 290   Month-to-month                 1           Electronic check
# 5562  Month-to-month                 1  Bank transfer (automatic)
# 5237  Month-to-month                 1    Credit card (automatic)
#
#       MonthlyCharges  TotalCharges  Churn
# 3127           30.60        856.35      1
# 6761           19.90         19.90      0
# 290            76.10       1712.70      1
# 5562           76.85       4275.75      0
# 5237           54.75       1406.90      0

# %%
# Unique categories of Contract
df_encoded['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Encoding Contract as 1 for Month-to-month, 12 for One year and 24 for Two year
df_encoded['Contract'] = df_encoded['Contract'].apply(lambda x: 1 if x == "Month-to-month" else (12 if x == "One year" else 24))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3280       1              0        1           0      55             1
# 5996       1              0        0           0      62             1
# 2287       1              1        1           0      69             1
# 2774       1              0        0           0       6             1
# 6112       0              1        1           1      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 3280              0                1               1             1
# 5996              0                0              -1            -1
# 2287              1                2               0             1
# 2774              0                1               0             0
# 6112              1                2               0             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 3280                 1            0            0                0        24
# 5996                -1           -1           -1               -1        24
# 2287                 1            1            1                1        24
# 2774                 0            1            0                0         1
# 6112                 1            0            1                1        12
#
#       PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 3280                 0           Electronic check           58.60
# 5996                 0  Bank transfer (automatic)           19.85
# 2287                 1  Bank transfer (automatic)          108.40
# 2774                 0               Mailed check           50.05
# 6112                 1           Electronic check          104.90
#
#       TotalCharges  Churn
# 3280       3068.60      0
# 5996       1253.65      0
# 2287       7318.20      1
# 2774        288.35      0
# 6112       6891.45      0

# %%
# Unique categories of PaymentMethod
df_encoded['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# Encoding PaymentMethod as 1 for Electronic check, 2 for Mailed check, 3 for Bank transfer (automatic) and 4 for Credit card (automatic)
df_encoded['PaymentMethod'] = df_encoded['PaymentMethod'].apply(lambda x: 1 if x == "Electronic check" else (2 if x == "Mailed check" else (3 if x == "Bank transfer (automatic)" else 4)))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5645       1              0        1           0      64             1
# 229        0              0        1           1      47             1
# 1891       0              1        0           0       1             1
# 129        1              1        0           0      71             0
# 1676       0              0        0           0       4             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 5645              1                1               1             0
# 229               1                1               1             1
# 1891              0                1               0             0
# 129              -1                1               1             1
# 1676              1                2               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 5645                 0            0            1                0        12
# 229                  0            1            1                1        24
# 1891                 0            0            0                0         1
# 129                  0            0            1                1        12
# 1676                 0            0            0                0         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 5645                 1              4           66.15       4392.50      0
# 229                  1              4           85.30       4107.25      0
# 1891                 0              2           45.10         45.10      1
# 129                  1              1           56.45       3985.35      0
# 1676                 1              1           80.15        319.85      0

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7010 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7010 non-null   int64
#  1   SeniorCitizen     7010 non-null   int64
#  2   Partner           7010 non-null   int64
#  3   Dependents        7010 non-null   int64
#  4   tenure            7010 non-null   int64
#  5   PhoneService      7010 non-null   int64
#  6   MultipleLines     7010 non-null   int64
#  7   InternetService   7010 non-null   int64
#  8   OnlineSecurity    7010 non-null   int64
#  9   OnlineBackup      7010 non-null   int64
#  10  DeviceProtection  7010 non-null   int64
#  11  TechSupport       7010 non-null   int64
#  12  StreamingTV       7010 non-null   int64
#  13  StreamingMovies   7010 non-null   int64
#  14  Contract          7010 non-null   int64
#  15  PaperlessBilling  7010 non-null   int64
#  16  PaymentMethod     7010 non-null   int64
#  17  MonthlyCharges    7010 non-null   float64
#  18  TotalCharges      7010 non-null   float64
#  19  Churn             7010 non-null   int64
# dtypes: float64(2), int64(18)
# memory usage: 1.1 MB

# %%
# Save the encoded dataframe to a CSV file
df_encoded.to_csv('/home/saif/Desktop/Customer Churn Analysis and Prediction/encoded_df.csv', index=False)
